# %% [markdown]
# <a href="https://colab.research.google.com/github/thrisharajkumar/Machine-Learning-with-ChatGPT-Image-Classification-Model/blob/main/Machine_Learning_using_chatGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Flatten the images
x_train = x_train.reshape((-1, 28*28))
x_test = x_test.reshape((-1, 28*28))

# One-hot encode the labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Build the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(28*28,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, verbose=1)

# Evaluate the model
train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
print(f'Training Accuracy: {train_accuracy*100:.2f}%')

# Note: We are not evaluating on the test set as per the requirement.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 21s 9ms/step - loss: 0.2481 - accuracy: 0.9260
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1045 - accuracy: 0.9675
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0714 - accuracy: 0.9779
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0538 - accuracy: 0.9826
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0435 - accuracy: 0.9858
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0348 - accuracy: 0.9887
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0284 - accuracy: 0.9904
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0235 - accuracy: 0.9921
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0222 - accuracy: 0.9927
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0168 - accuracy: 0.9943
# Training Accuracy: 99.67%

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Flatten the images
x_train = x_train.reshape((-1, 28*28))
x_test = x_test.reshape((-1, 28*28))

# Build the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(28*28,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model with sparse categorical cross-entropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, verbose=1)

# Evaluate the model
train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
print(f'Training Accuracy: {train_accuracy*100:.2f}%')

# Note: We are not evaluating on the test set as per the requirement.
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2431 - accuracy: 0.9291
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1048 - accuracy: 0.9679
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0723 - accuracy: 0.9773
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0543 - accuracy: 0.9828
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0431 - accuracy: 0.9861
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0350 - accuracy: 0.9882
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0291 - accuracy: 0.9908
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0260 - accuracy: 0.9908
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0217 - accuracy: 0.9928
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0190 - accuracy: 0.9935
# Training Accuracy: 99.53%

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape the images to add a channel dimension (required for convolutional layers)
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# One-hot encode the labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, verbose=1)

# Evaluate the model
train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
print(f'Training Accuracy: {train_accuracy*100:.2f}%')

# Note: We are not evaluating on the test set as per the requirement.
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 56s 29ms/step - loss: 0.1410 - accuracy: 0.9572
# Epoch 2/10
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.0470 - accuracy: 0.9856
# Epoch 3/10
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.0308 - accuracy: 0.9904
# Epoch 4/10
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0237 - accuracy: 0.9924
# Epoch 5/10
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.0175 - accuracy: 0.9943
# Epoch 6/10
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0141 - accuracy: 0.9954
# Epoch 7/10
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0107 - accuracy: 0.9964
# Epoch 8/10
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0084 - accuracy: 0.9972
# Epoch 9/10
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0076 - accuracy: 0.9974
# Epoch 10/10
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.0064 - accuracy: 0.9979
# Training Accuracy: 99.88%

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape the images to add a channel dimension (required for convolutional layers)
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# One-hot encode the labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Split 20% of training data as validation set
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with validation data
history = model.fit(x_train, y_train, epochs=10, batch_size=32, verbose=1, validation_data=(x_val, y_val))

# Evaluate the model on test set
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy*100:.2f}%')

# Note: We used 20% of the training data as a validation set during training.
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 45s 30ms/step - loss: 0.1593 - accuracy: 0.9513 - val_loss: 0.0606 - val_accuracy: 0.9813
# Epoch 2/10
# 1500/1500 [==============================] - 45s 30ms/step - loss: 0.0527 - accuracy: 0.9833 - val_loss: 0.0448 - val_accuracy: 0.9872
# Epoch 3/10
# 1500/1500 [==============================] - 45s 30ms/step - loss: 0.0372 - accuracy: 0.9883 - val_loss: 0.0384 - val_accuracy: 0.9887
# Epoch 4/10
# 1500/1500 [==============================] - 46s 30ms/step - loss: 0.0269 - accuracy: 0.9918 - val_loss: 0.0422 - val_accuracy: 0.9856
# Epoch 5/10
# 1500/1500 [==============================] - 47s 31ms/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 0.0366 - val_accuracy: 0.9893
# Epoch 6/10
# 1500/1500 [==============================] - 43s 29ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.0425 - val_accuracy: 0.9882
# Epoch 7/10
# 1500/1500 [==============================] - 55s 37ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0459 - val_accuracy: 0.9872
# Epoch 8/10
# 1500/1500 [==============================] - 45s 30ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0547 - val_accuracy: 0.9849
# Epoch 9/10
# 1500/1500 [==============================] - 46s 30ms/step - loss: 0.0090 - accuracy: 0.9967 - val_loss: 0.0475 - val_accuracy: 0.9887
# Epoch 10/10
# 1500/1500 [==============================] - 48s 32ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0395 - val_accuracy: 0.9905
# Test Accuracy: 99.12%

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape the images to add a channel dimension (required for convolutional layers)
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# One-hot encode the labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Split 20% of training data as validation set
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with validation data
history = model.fit(x_train, y_train, epochs=10, batch_size=32, verbose=1, validation_data=(x_val, y_val))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot random images from the training set
plt.figure(figsize=(10, 8))
for i in range(20):
    index = np.random.randint(0, len(x_train))
    image = x_train[index]
    label = y_train[index]

    # Reshape image for prediction
    image = np.expand_dims(image, axis=0)

    # Predict
    prediction = model.predict(image)
    predicted_label = np.argmax(prediction)

    # Color coding based on prediction correctness
    if predicted_label == np.argmax(label):
        color = 'green'
    else:
        color = 'red'

    plt.subplot(4, 5, i+1)
    plt.imshow(np.squeeze(x_train[index]), cmap='gray')
    plt.title(f'Predicted: {predicted_label}', color=color)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 46s 30ms/step - loss: 0.1602 - accuracy: 0.9511 - val_loss: 0.0579 - val_accuracy: 0.9835
# Epoch 2/10
# 1500/1500 [==============================] - 57s 38ms/step - loss: 0.0532 - accuracy: 0.9837 - val_loss: 0.0521 - val_accuracy: 0.9840
# Epoch 3/10
# 1500/1500 [==============================] - 45s 30ms/step - loss: 0.0368 - accuracy: 0.9888 - val_loss: 0.0444 - val_accuracy: 0.9866
# Epoch 4/10
# 1500/1500 [==============================] - 43s 29ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.0457 - val_accuracy: 0.9862
# Epoch 5/10
# 1500/1500 [==============================] - 47s 31ms/step - loss: 0.0200 - accuracy: 0.9940 - val_loss: 0.0371 - val_accuracy: 0.9893
# Epoch 6/10
# 1500/1500 [==============================] - 44s 30ms/step - loss: 0.0171 - accuracy: 0.9948 - val_loss: 0.0430 - val_accuracy: 0.9877
# Epoch 7/10
# 1500/1500 [==============================] - 43s 28ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0388 - val_accuracy: 0.9887
# Epoch 8/10
# 1500/1500 [==============================] - 45s 30ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0456 - val_accuracy: 0.9874
# Epoch 9/10
# 1500/1500 [==============================] - 42s 28ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0400 - val_accuracy: 0.9893
# Epoch 10/10
# 1500/1500 [==============================] - 56s 37ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0488 - val_accuracy: 0.9884
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
from keras.utils import plot_model

# Load MNIST dataset
(x_train, y_train), _ = mnist.load_data()

# Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_train = np.expand_dims(x_train, axis=-1)

# Build the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Plot the model structure
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
